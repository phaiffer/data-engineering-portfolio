# %%
from pathlib import Path
import json
import pandas as pd

# %%
project_root = Path.cwd().resolve().parents[0]

raw_dir = project_root / "data" / "bronze" / "raw" / "healthcare_analytics_patient_flow"
metadata_dir = project_root / "data" / "bronze" / "metadata"

# %%
metadata_files = list(metadata_dir.glob("*.json"))
metadata_files
# Out:
# [WindowsPath('C:/Users/willi/OneDrive/Área de Trabalho/PhaifferTech/repos/data-engineering-portfolio/projects/01-hospital-analytics/data/bronze/metadata/healthcare_analytics_patient_flow_bronze_metadata.json')]

# %%
metadata_path = metadata_files[0]
with open(metadata_path, "r", encoding="utf-8") as f:
    bronze_metadata = json.load(f)

bronze_metadata
# Out:
# {'dataset_handle': 'hassanjameelahmed/healthcare-analytics-patient-flow-data',
#  'local_raw_directory': 'data/bronze/raw/healthcare_analytics_patient_flow',
#  'generated_at_utc': '2026-04-12T15:47:00.748262+00:00',
#  'discovered_files': {'raw_directory': 'data/bronze/raw/healthcare_analytics_patient_flow',
#   'supported_extensions': ['.csv'],
#   'file_count': 2,
#   'supported_data_file_count': 1,
#   'files': [{'path': 'data/bronze/raw/healthcare_analytics_patient_flow/.complete/datasets/hassanjameelahmed/healthcare-analytics-patient-flow-data/1/bundle.complete',
#     'name': 'bundle.complete',
#     'extension': '.complete',
#     'size_bytes': 0,
#     'is_supported_data_file': False,
#     'is_selected_for_bronze_profiling': False},
#    {'path': 'data/bronze/raw/healthcare_analytics_patient_flow/healthcare_analytics_patient_flow_data.csv',
#     'name': 'healthcare_analytics_patient_flow_data.csv',
#     'extension': '.csv',
#     'size_bytes': 864047,
# ...

# %%
files = [path for path in raw_dir.rglob("*") if path.is_file()]
csv_files = [path for path in files if path.suffix.lower() == ".csv"]
csv_files
# Out:
# [WindowsPath('C:/Users/willi/OneDrive/Área de Trabalho/PhaifferTech/repos/data-engineering-portfolio/projects/01-hospital-analytics/data/bronze/raw/healthcare_analytics_patient_flow/healthcare_analytics_patient_flow_data.csv')]

# %%
dataset_path = csv_files[0]
df = pd.read_csv(dataset_path)

df.head()
# Out:
#     Patient Id Patient Admission Date Patient Admission Time        Merged  \
# 0  780-96-6113               9/9/2024             9:25:00 AM     W. Breede
# 1  714-35-6722               9/9/2024             4:42:00 PM   Y. Baldetti
# 2  571-85-3714               9/9/2024            12:14:00 AM    M. Semerad
# 3  404-43-9499               9/9/2024             8:33:00 PM    K. Blaydes
# 4  552-51-5855               9/9/2024             7:25:00 PM  F. Dickerson
#
#   Patient Gender  Patient Age      Patient Race Department Referral  \
# 0         Female           63  African American                 NaN
# 1           Male           31             Asian         Orthopedics
# 2           Male           75             White    General Practice
# 3           Male           79  African American    General Practice
# 4         Female           24  African American                 NaN
#
#   Patient Admission Flag  Patient Satisfaction Score  Patient Waittime
# ...

# %%
df.shape
# Out:
# (9216, 11)

# %%
df.columns.tolist()
# Out:
# ['Patient Id',
#  'Patient Admission Date',
#  'Patient Admission Time',
#  'Merged',
#  'Patient Gender',
#  'Patient Age',
#  'Patient Race',
#  'Department Referral',
#  'Patient Admission Flag',
#  'Patient Satisfaction Score',
#  'Patient Waittime']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9216 entries, 0 to 9215
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Patient Id                  9216 non-null   str
#  1   Patient Admission Date      9216 non-null   str
#  2   Patient Admission Time      9216 non-null   str
#  3   Merged                      9216 non-null   str
#  4   Patient Gender              9216 non-null   str
#  5   Patient Age                 9216 non-null   int64
#  6   Patient Race                9216 non-null   str
#  7   Department Referral         3816 non-null   str
#  8   Patient Admission Flag      9216 non-null   str
#  9   Patient Satisfaction Score  2517 non-null   float64
#  10  Patient Waittime            9216 non-null   int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 1.4 MB

# %%
df.describe(include="all")
# Out:
#          Patient Id Patient Admission Date Patient Admission Time     Merged  \
# count          9216                   9216                   9216       9216
# unique         9216                    579                   1437       9185
# top     780-96-6113              12/4/2023             9:34:00 AM  J. Piggen
# freq              1                     30                     16          2
# mean            NaN                    NaN                    NaN        NaN
# std             NaN                    NaN                    NaN        NaN
# min             NaN                    NaN                    NaN        NaN
# 25%             NaN                    NaN                    NaN        NaN
# 50%             NaN                    NaN                    NaN        NaN
# 75%             NaN                    NaN                    NaN        NaN
# max             NaN                    NaN                    NaN        NaN
#
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Patient Satisfaction Score    6699
# Department Referral           5400
# Patient Id                       0
# Patient Admission Time           0
# Patient Admission Date           0
# Merged                           0
# Patient Gender                   0
# Patient Race                     0
# Patient Age                      0
# Patient Admission Flag           0
# Patient Waittime                 0
# dtype: int64

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# Patient Satisfaction Score    0.726888
# Department Referral           0.585938
# Patient Id                    0.000000
# Patient Admission Time        0.000000
# Patient Admission Date        0.000000
# Merged                        0.000000
# Patient Gender                0.000000
# Patient Race                  0.000000
# Patient Age                   0.000000
# Patient Admission Flag        0.000000
# Patient Waittime              0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique().sort_values()
# Out:
# Patient Admission Flag           2
# Patient Gender                   3
# Department Referral              7
# Patient Race                     7
# Patient Satisfaction Score      11
# Patient Waittime                51
# Patient Age                     79
# Patient Admission Date         579
# Patient Admission Time        1437
# Merged                        9185
# Patient Id                    9216
# dtype: int64
