# %% [markdown]
# # Silver Output Validation
#
# Lightweight validation notebook for the generated Silver v1 job-market artifact.
#
# Pipeline logic belongs under `src/`; this notebook only inspects the output.

# %%
from pathlib import Path
import pandas as pd

cwd = Path.cwd()
if (cwd / "data" / "silver").exists():
    PROJECT_ROOT = cwd
elif cwd.name == "notebooks" and (cwd.parent / "data" / "silver").exists():
    PROJECT_ROOT = cwd.parent
elif (cwd / "projects" / "02-job-market-analytics" / "data" / "silver").exists():
    PROJECT_ROOT = cwd / "projects" / "02-job-market-analytics"
else:
    raise RuntimeError("Launch this notebook from the project directory, notebook directory, or repository root.")

silver_path = PROJECT_ROOT / "data" / "silver" / "ai_job_market_insights_silver.csv"
silver_path
# Out:
# WindowsPath('c:/Users/willi/OneDrive/Área de Trabalho/PhaifferTech/repos/data-engineering-portfolio/projects/02-job-market-analytics/data/silver/ai_job_market_insights_silver.csv')

# %%
df = pd.read_csv(silver_path)
df.head()
# Out:
#                job_title       industry company_size   location  \
# 0  cybersecurity_analyst  entertainment        small      dubai
# 1   marketing_specialist     technology        large  singapore
# 2          ai_researcher     technology        large  singapore
# 3          sales_manager         retail        small     berlin
# 4  cybersecurity_analyst  entertainment        small      tokyo
#
#   ai_adoption_level automation_risk     required_skills     salary_usd  \
# 0            medium            high        ux_ui_design  111392.165243
# 1            medium            high           marketing   93792.562466
# 2            medium            high        ux_ui_design  107170.263069
# 3               low            high  project_management   93027.953758
# 4               low             low          javascript   87752.922171
#
#   remote_friendly job_growth_projection
# 0             yes                growth
# 1              no               decline
# 2             yes                growth
# 3              no                growth
# 4             yes               decline

# %%
df.shape
# Out:
# (500, 10)

# %%
list(df.columns)
# Out:
# ['job_title',
#  'industry',
#  'company_size',
#  'location',
#  'ai_adoption_level',
#  'automation_risk',
#  'required_skills',
#  'salary_usd',
#  'remote_friendly',
#  'job_growth_projection']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title              500 non-null    str
#  1   industry               500 non-null    str
#  2   company_size           500 non-null    str
#  3   location               500 non-null    str
#  4   ai_adoption_level      500 non-null    str
#  5   automation_risk        500 non-null    str
#  6   required_skills        500 non-null    str
#  7   salary_usd             500 non-null    float64
#  8   remote_friendly        500 non-null    str
#  9   job_growth_projection  500 non-null    str
# dtypes: float64(1), str(9)
# memory usage: 72.0 KB

# %% [markdown]
# ## Basic Sanity Checks

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# job_title                0
# industry                 0
# company_size             0
# location                 0
# ai_adoption_level        0
# automation_risk          0
# required_skills          0
# salary_usd               0
# remote_friendly          0
# job_growth_projection    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["salary_usd"].describe()
# Out:
# count       500.000000
# mean      91222.390974
# std       20504.291453
# min       31969.526346
# 25%       78511.514863
# 50%       91998.195286
# 75%      103971.282092
# max      155209.821614
# Name: salary_usd, dtype: float64

# %%
for column in ["company_size", "ai_adoption_level", "automation_risk", "remote_friendly", "job_growth_projection"]:
    print(column)
    print(sorted(df[column].dropna().unique()))
    print()
# Out:
# company_size
# ['large', 'medium', 'small']
#
# ai_adoption_level
# ['high', 'low', 'medium']
#
# automation_risk
# ['high', 'low', 'medium']
#
# remote_friendly
# ['no', 'yes']
#
# job_growth_projection
# ['decline', 'growth', 'stable']

# %% [markdown]
# ## Notes
#
# - Row count should match the Bronze-selected source file.
# - Categorical values should be normalized lowercase tokens.
# - `salary_usd` should be numeric and ready for future Gold salary-band logic.
# - Future DBT work can use this output as the stable row-level staging contract.
